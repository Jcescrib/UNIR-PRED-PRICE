# 2021-04-30 23:59:59.999     5.538852e+10
# 2021-05-31 23:59:59.999     7.508161e+10
# 2021-06-30 23:59:59.999     5.035913e+10
# 2021-07-31 23:59:59.999     3.062281e+10
# 2021-08-31 23:59:59.999     3.687813e+10
# 2021-09-30 23:59:59.999     3.435290e+10
# 2021-10-31 23:59:59.999     4.500201e+10
# 2021-11-30 23:59:59.999     3.841308e+10
# 2021-12-31 23:59:59.999     2.955820e+10
# 2022-01-31 23:59:59.999     2.523482e+10
# 2022-02-28 23:59:59.999     2.504702e+10
# 2022-03-31 23:59:59.999     3.109333e+10
# 2022-04-30 23:59:59.999     2.589732e+10
# 2022-05-31 23:59:59.999     3.641370e+10
# 2022-06-30 23:59:59.999     3.240148e+10
# 2022-07-31 23:59:59.999     5.430286e+10

# %% [markdown]
# ### Definición del la frequencia

# %%
df=df.asfreq('6h')
df=df.fillna(method='ffill')
df.isnull().sum()
# Out:
# open               0
# high               0
# low                0
# close              0
# volume             0
# qav                0
# num_trades         0
# taker_base_vol     0
# taker_quote_vol    0
# dtype: int64

# %% [markdown]
# ## Análisis estadístico de los datos

# %% [markdown]
# ### Revisar los datos: head()
#
# Puede revisar las primeras 20 filas de sus datos utilizando la función `head()` en el DataFrame de Pandas. Puede ver que la primera columna enumera el número de fila, lo cual es útil para hacer referencia a una observación específica.

# %%
df.head()
# Out:
#                             open     high     low    close       volume  \
# Date
# 2017-09-30 23:59:59.999  4689.89  4939.19  2817.0  4378.51  27634.18912
# 2017-10-01 00:59:59.999  4689.89  4939.19  2817.0  4378.51  27634.18912
# 2017-10-01 01:59:59.999  4689.89  4939.19  2817.0  4378.51  27634.18912
# 2017-10-01 02:59:59.999  4689.89  4939.19  2817.0  4378.51  27634.18912
# 2017-10-01 03:59:59.999  4689.89  4939.19  2817.0  4378.51  27634.18912
#
#                                   qav  num_trades  taker_base_vol  \
# Date
# 2017-09-30 23:59:59.999  1.104931e+08    228745.0    12353.170043
# 2017-10-01 00:59:59.999  1.104931e+08    228745.0    12353.170043
# 2017-10-01 01:59:59.999  1.104931e+08    228745.0    12353.170043
# 2017-10-01 02:59:59.999  1.104931e+08    228745.0    12353.170043
# 2017-10-01 03:59:59.999  1.104931e+08    228745.0    12353.170043
#
#                          taker_quote_vol
# Date
# 2017-09-30 23:59:59.999     4.919992e+07
# 2017-10-01 00:59:59.999     4.919992e+07
# 2017-10-01 01:59:59.999     4.919992e+07
# 2017-10-01 02:59:59.999     4.919992e+07
# 2017-10-01 03:59:59.999     4.919992e+07

# %% [markdown]
# ### Dimensiones de los datos: shape
#
# Puede revisar la forma y el tamaño de su conjunto de datos imprimiendo la propiedad shape en el DataFrame de Pandas. Los resultados se enumeran en filas y luego en columnas.

# %%
df.shape
# Out:
# (42361, 9)

# %% [markdown]
# ### Tipos de atributos: dtypes
#
# Puede enumerar los tipos de datos utilizados por el DataFrame para caracterizar cada atributo utilizando la propiedad `dtypes`.

# %%
df.dtypes
# Out:
# open               float64
# high               float64
# low                float64
# close              float64
# volume             float64
# qav                float64
# num_trades         float64
# taker_base_vol     float64
# taker_quote_vol    float64
# dtype: object

# %% [markdown]
# ### Resumen estadístico: describe()
#
# Puedes ver que obtienes muchos datos. Notará algunas llamadas como `pandas.set_option()` utilizada para cambiar la precisión de los números y el ancho preferido de la salida. Esto es para que sea más legible para este ejemplo. Al describir sus datos de esta manera, vale la pena tomarse un tiempo y revisar las observaciones de los resultados.

# %%
# Statistical Summary
pd.set_option('display.width', 100)
pd.set_option('display.precision', 3)
df.describe()
# Out:
#             open       high        low      close     volume        qav  num_trades  \
# count  42361.000  42361.000  42361.000  42361.000  4.236e+04  4.236e+04   4.236e+04
# mean   19314.939  23197.060  15884.292  19584.636  1.567e+06  3.481e+10   2.462e+07
# std    17471.892  20310.907  14273.806  17355.904  7.896e+05  3.760e+10   2.044e+07
# min     3434.100   4069.800   2817.000   3434.100  2.763e+04  1.105e+08   2.287e+05
# 25%     7011.210   9074.260   6070.000   7195.230  1.117e+06  7.956e+09   7.421e+06
# 50%     9588.740  11710.000   8445.000   9838.960  1.499e+06  1.550e+10   1.701e+07
# 75%    35045.000  41950.000  28805.000  35045.000  1.886e+06  6.094e+10   4.023e+07
# max    61299.810  69000.000  53256.640  61299.800  4.983e+06  1.550e+11   1.226e+08
#
#        taker_base_vol  taker_quote_vol
# count       4.236e+04        4.236e+04
# mean        7.792e+05        1.718e+10
# std         3.805e+05        1.843e+10
# min         1.235e+04        4.920e+07
# 25%         5.903e+05        4.259e+09
# 50%         7.339e+05        7.693e+09
# 75%         9.057e+05        2.956e+10
# max         2.494e+06        7.508e+10

# %% [markdown]
# ### Correlaciones: corr()
#
# Puede usar la función corr() para calcular una matriz de correlación. La matriz enumera todos los atributos en la parte superior y lateral, para dar correlación entre todos los pares de atributos (dos veces, porque la matriz es simétrica). Puede ver que la línea diagonal a través de la matriz desde las esquinas superior izquierda a inferior derecha de la matriz muestra una correlación perfecta de cada atributo consigo mismo.

# %%
# Pairwise Pearson correlations
df.corr()
# Out:
#                   open   high    low  close  volume    qav  num_trades  taker_base_vol  \
# open             1.000  0.975  0.971  0.947   0.340  0.868       0.819           0.328
# high             0.975  1.000  0.983  0.985   0.352  0.902       0.853           0.342
# low              0.971  0.983  1.000  0.986   0.290  0.848       0.805           0.280
# close            0.947  0.985  0.986  1.000   0.316  0.868       0.829           0.308
# volume           0.340  0.352  0.290  0.316   1.000  0.629       0.736           0.999
# qav              0.868  0.902  0.848  0.868   0.629  1.000       0.973           0.622
# num_trades       0.819  0.853  0.805  0.829   0.736  0.973       1.000           0.727
# taker_base_vol   0.328  0.342  0.280  0.308   0.999  0.622       0.727           1.000
# taker_quote_vol  0.868  0.903  0.850  0.871   0.626  1.000       0.972           0.620
#
#                  taker_quote_vol
# open                       0.868
# high                       0.903
# low                        0.850
# close                      0.871
# volume                     0.626
# qav                        1.000
# num_trades                 0.972
# taker_base_vol             0.620
# taker_quote_vol            1.000

# %% [markdown]
# ### Matriz de correlación

# %%
import matplotlib.pyplot as plt
import seaborn as sns
correlation = df.corr()
plt.figure (figsize=(10,10))
ax= sns.heatmap(correlation, vmax=1, square= True, annot= True, cmap='viridis')
plt.title("Matriz de correlación")
plt.show()

# %% [markdown]
# ### Asimetría: skew()
#
# Puede calcular el sesgo de cada atributo utilizando la función skew(). El resultado de inclinación muestra una inclinación positiva (derecha) o negativa (izquierda). Los valores más cercanos a cero muestran menos sesgo.

# %%
df.skew()
# Out:
# open               1.049
# high               0.958
# low                1.064
# close              1.031
# volume             0.687
# qav                1.297
# num_trades         0.916
# taker_base_vol     0.636
# taker_quote_vol    1.287
# dtype: float64

# %% [markdown]
# ## Análisis de la distribución

# %% [markdown]
# ### The QQ Plot

# %%
import scipy.stats

# %%
scipy.stats.probplot(df.open, plot =  plt)
plt.title("QQ Plot-Open", size = 24)
plt.show()

scipy.stats.probplot(df.high, plot =  plt)
plt.title("QQ Plot-high", size = 24)
plt.show()

scipy.stats.probplot(df.low, plot =  plt)
plt.title("QQ Plot-low", size = 24)
plt.show()

scipy.stats.probplot(df.close, plot =  plt)
plt.title("QQ Plot-close", size = 24)
plt.show()

scipy.stats.probplot(df.volume, plot =  plt)
plt.title("QQ Plot-volume", size = 24)
plt.show()

scipy.stats.probplot(df.num_trades, plot =  plt)
plt.title("QQ Plot-num_trades", size = 24)
plt.show()

scipy.stats.probplot(df.qav, plot =  plt)
plt.title("QQ Plot-qav", size = 24)
plt.show()

scipy.stats.probplot(df.taker_base_vol, plot =  plt)
plt.title("QQ Plot-taker_base_vol", size = 24)
plt.show()

scipy.stats.probplot(df.taker_quote_vol, plot =  plt)
plt.title("QQ Plot-taker_quote_vol", size = 24)
plt.show()

# %% [markdown]
# ## Matriz de dispersión

# %%
# %matplotlib inline
# Correlatioin matrix Seaborn
sns.pairplot(df)

# %% [markdown]
# # Representación gráfica del análisis histórico de datos del BTC-USDT entre el 18-08-2017 y el 31-07-2022
#
#
# ---
#
# ## Visualización de los datos

# %% [markdown]
# ## Visualización de los datos

# %% [markdown]
# Visualización de los precios Open, Hight, Low, y Close

# %%
df.plot.line(title='BTC-USDT (Open)',y='open',figsize=(20,5),lw=1, color="blue")
df.plot.line(title='BTC-USDT (Hight)',y='high',figsize=(20,5),lw=1, color="blue")
df.plot.line(title='BTC-USDT (Low)',y='low',figsize=(20,5),lw=1, color="blue")
df.plot.line(title='BTC-USDT (Close)',y='close',figsize=(20,5),lw=1, color="blue")

# %% [markdown]
# Visualización del qav

# %%
df.plot.line(title='BTC-USDT (Quote asset volume)',y='qav',figsize=(20,5),lw=1, color="red")

# %% [markdown]
# Visualización del número de transacciones (num_trades)

# %%
df.plot.line(title='BTC-USDT (Num_trades)',y='num_trades',figsize=(20,5),lw=1, color="green")

# %% [markdown]
# Visualización del número de transacciones (taker_base_vol)

# %%
df.plot.line(title='BTC-USDT (Taker_base_vol)',y='taker_base_vol',figsize=(20,5),lw=1, color="purple")

# %% [markdown]
# Visualización del número de transacciones (taker_quote_vol)

# %%
df.plot.line(title='BTC-USDT (Taker_quote_vol)',y='taker_quote_vol',figsize=(20,5),lw=1, color="orange")

# %% [markdown]
# # Análisis de la estacionaridad test Dickey-Fuller
#
# ## Importar librerias

# %%
import statsmodels.tsa.stattools as sts
import statsmodels.graphics.tsaplots as sgt

# %% [markdown]
# Dickey-Fuller de Open

# %%
sts.adfuller(df.open)
# Out:
# (-1.3772825933986066,
#  0.5931173811952536,
#  0,
#  42360,
#  {'1%': -3.430504383765683,
#   '5%': -2.861608234182604,
#   '10%': -2.5668063188459054},
#  572458.1309224499)

# %% [markdown]
# Dickey-Fuller de High

# %%
sts.adfuller(df.high)
# Out:
# (-1.2413056242634735,
#  0.6555796069038293,
#  0,
#  42360,
#  {'1%': -3.430504383765683,
#   '5%': -2.861608234182604,
#   '10%': -2.5668063188459054},
#  571428.5947059611)

# %% [markdown]
# Dickey-Fuller de Low

# %%
sts.adfuller(df.low)
# Out:
# (-1.4213097245876534,
#  0.5720184123217318,
#  0,
#  42360,
#  {'1%': -3.430504383765683,
#   '5%': -2.861608234182604,
#   '10%': -2.5668063188459054},
#  557238.0825944032)

# %% [markdown]
# Dickey-Fuller de Close

# %%
sts.adfuller(df.close)
# Out:
# (-1.392341194116533,
#  0.5859422888069721,
#  0,
#  42360,
#  {'1%': -3.430504383765683,
#   '5%': -2.861608234182604,
#   '10%': -2.5668063188459054},
#  572704.1664910371)

# %% [markdown]
# Dickey-Fuller de Volumen

# %%
sts.adfuller(df.volume)
# Out:
# (-1.952186130274007,
#  0.3079229895071477,
#  0,
#  42360,
#  {'1%': -3.430504383765683,
#   '5%': -2.861608234182604,
#   '10%': -2.5668063188459054},
#  973783.3809295503)

# %% [markdown]
# Dickey-Fuller de QAV

# %%
sts.adfuller(df.qav)
# Out:
# (-1.1863390558289812,
#  0.6794445258536898,
#  0,
#  42360,
#  {'1%': -3.430504383765683,
#   '5%': -2.861608234182604,
#   '10%': -2.5668063188459054},
#  1830238.0231291486)

# %% [markdown]
# Dickey-Fuller de Num_trades

# %%
sts.adfuller(df.num_trades)
# Out:
# (-0.30891852529832864,
#  0.9242316698863696,
#  0,
#  42360,
#  {'1%': -3.430504383765683,
#   '5%': -2.861608234182604,
#   '10%': -2.5668063188459054},
#  1229129.8437725238)

# %% [markdown]
# Dickey-Fuller de Taker_base_vol

# %%
sts.adfuller(df.taker_base_vol)
# Out:
# (-1.9351626189275966,
#  0.31570452826173045,
#  0,
#  42360,
#  {'1%': -3.430504383765683,
#   '5%': -2.861608234182604,
#   '10%': -2.5668063188459054},
#  913713.0141245871)

# %% [markdown]
# Dickey-Fuller de Taker_quote_vol

# %%
sts.adfuller(df.taker_quote_vol)
# Out:
# (-1.1530805698187272,
#  0.6934468752519961,
#  0,
#  42360,
#  {'1%': -3.430504383765683,
#   '5%': -2.861608234182604,
#   '10%': -2.5668063188459054},
#  1769849.7484725157)

# %% [markdown]
# # Análisis de la estacionalidad
#
# ## Importar librerias

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# Evaluación de la estacionalidad del Open de forma aditiva y de forma multiplicativa

# %%
df.sort_index(inplace=True)
result = seasonal_decompose(df['open'], model='additive')  
fig = result.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()

# %%
df.sort_index(inplace=True)
result = seasonal_decompose(df['open'], model='multiplicative')  
fig = result.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()

# %% [markdown]
# Evaluación de la estacionalidad del Quote asset volume (QAV)

# %%
df.sort_index(inplace=True)
result = seasonal_decompose(df['qav'], model='additive')  
fig = result.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()

# %%
df.sort_index(inplace=True)
result = seasonal_decompose(df['qav'], model='multiplicative')  
fig = result.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()

# %% [markdown]
# Evaluación de la estacionalidad del Número de trades (num_trades)

# %%
df.sort_index(inplace=True)
result = seasonal_decompose(df['num_trades'], model='additive')  
fig = result.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()

# %%
df.sort_index(inplace=True)
result = seasonal_decompose(df['num_trades'], model='multiplicative')  
fig = result.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()

# %% [markdown]
# Evaluación de la estacionalidad del Taker buy base asset volume (taker_base_vol)

# %%
df.sort_index(inplace=True)
result = seasonal_decompose(df['taker_base_vol'], model='additive')  
fig = result.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()

# %%
df.sort_index(inplace=True)
result = seasonal_decompose(df['taker_base_vol'], model='multiplicative')  
fig = result.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()

# %% [markdown]
# Evaluación de la estacionalidad del Taker buy quote asset volume (taker_quote_vol)

# %%
df.sort_index(inplace=True)
result = seasonal_decompose(df['taker_quote_vol'], model='additive')  
fig = result.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()

# %%
df.sort_index(inplace=True)
result = seasonal_decompose(df['taker_quote_vol'], model='multiplicative')  
fig = result.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()
